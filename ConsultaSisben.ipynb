# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException, UnexpectedAlertPresentException
import time
import random
from selenium.webdriver.chrome.service import Service

# %%
# --- Configuración ---
# Reemplaza con la ruta real a tu archivo Excel
EXCEL_PATH = 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1).xlsx'
# Reemplaza con el nombre de la hoja si no es la primera
SHEET_NAME = 'Hoja1'    
# Reemplaza con los nombres exactos de tus columnas
COL_TIPO_DOC = 'TIPO IDENTIFICACION'
COL_NUM_DOC = 'NUMERO DOCUMENTO'
# Nueva columna para guardar el resultado
COL_RESULTADO = 'Estado_Sisben'
# Reemplaza con la URL real de la página de consulta del Sisbén
URL_SISBEN = 'https://reportes.sisben.gov.co/dnp_sisbenconsulta' # ¡Importante! Debes poner la URL correcta aquí
# Ruta al ejecutable del WebDriver que descargaste
WEBDRIVER_PATH = r'C:\chromedriver.exe' # O geckodriver, etc.

# Tiempos de espera (en segundos)
MIN_DELAY = 1  # Pausa mínima entre consultas
MAX_DELAY = 4 # Pausa máxima entre consultas
WAIT_TIMEOUT = 4 # Tiempo máximo de espera para que aparezcan elementos

# --- Mapeo de Tipos de Documento (EJEMPLO - AJUSTAR SEGÚN LA WEB) ---
# Debes averiguar los valores exactos que usa el <select> en la web
# El formato es: { 'Texto en tu Excel': 'valor_del_option_en_HTML' }
MAPEO_TIPO_DOC = {
    'RC': '1', # Cédula de Ciudadanía (Ejemplo)
    'TI': '2', # Cédula de Extranjería (Ejemplo)
    'CC': '3', # Tarjeta de Identidad (Ejemplo)
    'CE': '4', # Registro Civil (Ejemplo)
    # Agrega más tipos si es necesario
}

# --- Funciones Auxiliares ---
def configurar_driver():
    """Configura e inicia el WebDriver."""
    # Opciones para el navegador (puedes añadir más)
    options = webdriver.ChromeOptions()
    #options.add_argument('--headless')  # Ejecutar sin abrir ventana de navegador (puede ser detectado)
    options.add_argument('--disable-gpu')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    try:
        driver = webdriver.Chrome(executable_path=WEBDRIVER_PATH, options=options)
        return driver
    except Exception as e:
        print(f"Error al iniciar WebDriver: {e}")
        print(f"Asegúrate de que la ruta '{WEBDRIVER_PATH}' es correcta y el WebDriver es compatible con tu navegador.")
        return None

def consultar_sisben(driver, tipo_doc_excel, num_doc):
    """Realiza una única consulta en la página del Sisbén."""
    try:
        driver.get(URL_SISBEN)
        wait = WebDriverWait(driver, WAIT_TIMEOUT)

        # --- ¡IMPORTANTE! AJUSTA LOS LOCALIZADORES (By.ID, By.NAME, etc.) ---
        # Estos son ejemplos, DEBES encontrarlos inspeccionando la página real

        # 1. Seleccionar Tipo de Documento
        try:
            tipo_doc_select_element = wait.until(EC.presence_of_element_located((By.ID, 'TipoID'))) # Reemplaza 'id_del_dropdown_tipo_doc'
            select = Select(tipo_doc_select_element)
            valor_html = MAPEO_TIPO_DOC.get(str(tipo_doc_excel).strip().upper())
            if not valor_html:
                print(f"Advertencia: Tipo de documento '{tipo_doc_excel}' no mapeado. Saltando.")
                return "Error: Tipo Doc No Mapeado"
            select.select_by_value(valor_html) # O select_by_visible_text si prefieres
        except (NoSuchElementException, TimeoutException):
            print("Error: No se encontró el dropdown de tipo de documento.")
            return "Error: Elemento no encontrado (Tipo Doc)"
        except Exception as e:
            print(f"Error seleccionando tipo de documento: {e}")
            return "Error: Selección Tipo Doc"


        # 2. Ingresar Número de Documento
        try:
            num_doc_input = wait.until(EC.presence_of_element_located((By.ID, 'documento'))) # Reemplaza 'id_del_input_numero_doc'
            num_doc_input.clear()
            num_doc_input.send_keys(str(num_doc).strip())
        except (NoSuchElementException, TimeoutException):
            print("Error: No se encontró el campo de número de documento.")
            return "Error: Elemento no encontrado (Num Doc)"
        except Exception as e:
            print(f"Error ingresando número de documento: {e}")
            return "Error: Input Num Doc"


        # 3. Hacer clic en Consultar
        try:
            # Puede haber alertas inesperadas ANTES de hacer clic si llenaste mal algo
            boton_consultar = wait.until(EC.element_to_be_clickable((By.ID, 'botonenvio'))) # Reemplaza 'id_del_boton_consultar'
            boton_consultar.click()
        except UnexpectedAlertPresentException:
            try:
                alert = driver.switch_to.alert
                alert_text = alert.text
                print(f"Alerta inesperada ANTES de consultar: {alert_text}")
                alert.accept()
                return f"Alerta Previa: {alert_text}"
            except Exception as alert_err:
                print(f"Error manejando alerta previa: {alert_err}")
                return "Error: Manejo Alerta Previa"
        except (NoSuchElementException, TimeoutException):
            print("Error: No se encontró el botón de consultar.")
            return "Error: Elemento no encontrado (Botón)"
        except Exception as e:
            print(f"Error haciendo clic en consultar: {e}")
            return "Error: Clic Consultar"

        # 4. Esperar y obtener resultado
        time.sleep(1) # Pequeña pausa para que la página reaccione

        resultado = "No Determinado"
        try:
            # Intenta manejar una alerta (ventana emergente)
            alert = wait.until(EC.alert_is_present())
            alert_text = alert.text
            if "El tipo de identificación" in alert_text.lower() or "NO se encuentra en la base" in alert_text.lower(): # Ajusta según el texto real
                resultado = "No tiene Sisben (Alerta)"
            else:
                resultado = f"Alerta: {alert_text}" # Podría ser otro mensaje
            alert.accept()

        except TimeoutException:
            # Si no hay alerta, busca el resultado en la página
            persona_con_sisben = False
            elementos_exito = [
                (By.XPATH, '/html/body/div[1]/main/div/div[1]/div[3]/div/div/div[2]/div[1]/p[1]'), # Ejemplo XPATH (puede que necesites varios)
                # Agrega aquí más XPaths para la imagen, nombres o apellidos
                (By.XPATH, '/html/body/div[1]/main/div/div[1]/div[1]/img'),
                (By.XPATH, '/html/body/div[1]/main/div/div[1]/div[3]/div/div/div[2]/div[1]/p[1]'),
                (By.XPATH, '/html/body/div[1]/main/div/div[1]/div[3]/div/div/div[2]/div[2]/p[1]')
            ]

            for by, path in elementos_exito:
                try:
                    wait.until(EC.presence_of_element_located((by, path)))
                    persona_con_sisben = True
                    break # Si encontramos al menos uno, asumimos que tiene Sisbén
                except TimeoutException:
                    pass # Si no se encuentra este elemento, probamos el siguiente

            if persona_con_sisben:
                resultado = "Registrado, persona con sisben"
            else:
                # Si no se encuentra ningún elemento de éxito, busca un mensaje de no encontrado en la página
                try:
                    # ¡DEBES AJUSTAR ESTE LOCALIZADOR!
                    mensaje_no_encontrado = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="swal2-content"]')))# Ejemplo XPATH
                    if mensaje_no_encontrado:
                        resultado = "No Registrado , no tiene sisben"
                except TimeoutException:
                    print("No se pudo determinar el resultado (ni alerta, ni elemento de éxito/fracaso encontrado en tiempo).")
                    resultado = "Error: Resultado Indeterminado"
                except Exception as e:
                    print(f"Error buscando mensaje de no encontrado en la página: {e}")
                    resultado = "Error: Buscando Mensaje No Encontrado"

        except Exception as e:
            print(f"Error general al obtener resultado: {e}")
            resultado = f"Error: {e}"

        return resultado

    except UnexpectedAlertPresentException:
        try:
            alert = driver.switch_to.alert
            alert_text = alert.text
            print(f"Alerta inesperada durante la consulta: {alert_text}")
            alert.accept()
            return f"Error: Alerta Inesperada ({alert_text})"
        except Exception as alert_err:
            print(f"Error manejando alerta inesperada: {alert_err}")
            return "Error: Manejo Alerta Inesperada"
    except Exception as e:
        print(f"Error crítico en la consulta para {num_doc}: {e}")
        # Intenta refrescar o navegar de nuevo en caso de error grave
        try:
            driver.refresh()
        except:
            pass # Ignora si no se puede refrescar
        return "Error Crítico"


# --- Script Principal ---
if __name__ == "__main__":
    print("Iniciando proceso de consulta Sisbén...")

    # Cargar datos de Excel
    try:
        df = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_NAME,header=6)
        print(f"Archivo Excel '{EXCEL_PATH}' cargado. {len(df)} registros encontrados.")
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo Excel en '{EXCEL_PATH}'")
        exit()
    except Exception as e:
        print(f"Error al leer el archivo Excel: {e}")
        exit()

    # Añadir columna de resultados si no existe
    if COL_RESULTADO not in df.columns:
        df[COL_RESULTADO] = ""

    # Iniciar WebDriver
    driver = configurar_driver()
    if not driver:
        exit()

    print("WebDriver iniciado.")

    # *** MODIFICACIÓN PARA INICIAR DESDE LA FILA 2890 ***
    start_row = 3540
    # Recuerda que los índices en pandas empiezan desde 0, y ya has leído el encabezado (6 filas).
    # Asumimos que quieres empezar desde la fila 2890 de los DATOS después del encabezado.
    # Esto correspondería al índice 2889 en el DataFrame.
    df_subset = df.iloc[start_row - 1:] # El slicing es exclusivo del final, así que usamos start_row - 1

    # Iterar sobre las filas del DataFrame a partir de la fila especificada
    for index, row in df_subset.iterrows():
        # El resto de tu código del bucle for se mantiene igual
        # Opcional: Saltar filas ya procesadas (si tienen un valor en COL_RESULTADO)
        if pd.notna(row[COL_RESULTADO]) and row[COL_RESULTADO] != "":
            print(f"Registro (original index {df.index[index] + 1}) ya procesado. Saltando.")
            continue

        tipo_doc = row[COL_TIPO_DOC]
        num_doc = row[COL_NUM_DOC]

        # Validar datos básicos
        if pd.isna(tipo_doc) or pd.isna(num_doc):
            print(f"Registro (original index {df.index[index] + 1}): Datos incompletos (Tipo={tipo_doc}, Num={num_doc}). Saltando.")
            df.loc[index, COL_RESULTADO] = "Error: Datos Incompletos"
            continue

        print(f"Consultando registro (original index {df.index[index] + 1}): Tipo={tipo_doc}, Num={num_doc}")

        # Realizar la consulta
        resultado_consulta = consultar_sisben(driver, tipo_doc, num_doc)
        df.loc[index, COL_RESULTADO] = resultado_consulta
        print(f"Resultado: {resultado_consulta}")

        # Guardar progreso cada X iteraciones
        if (index + 1) % 30 == 0:
            try:
                output_filename = f"{EXCEL_PATH.replace('.xlsx', '')}_progreso_{df.index[index]+1}.xlsx" # Guarda con el índice original
                df.to_excel(output_filename, index=False)
                print(f"Progreso guardado en '{output_filename}'")
            except Exception as e:
                print(f"Error al guardar el progreso: {e}")

        # Pausa aleatoria para evitar bloqueos
        delay = random.uniform(MIN_DELAY, MAX_DELAY)
        print(f"Esperando {delay:.2f} segundos...")
        time.sleep(delay)

    # Cerrar el navegador
    print("Cerrando el navegador...")
    driver.quit()

    # Guardar el resultado final
    try:
        output_filename_final = f"{EXCEL_PATH.replace('.xlsx', '')}_RESULTADOS_FINAL.xlsx"
        df.to_excel(output_filename_final, index=False)
        print(f"¡Proceso completado! Resultados guardados en '{output_filename_final}'")
    except Exception as e:
        print(f"Error al guardar el archivo final: {e}")

    print("Fin del script.")
# Out:
# Iniciando proceso de consulta Sisbén...
# Archivo Excel 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1).xlsx' cargado. 8096 registros encontrados.
# C:\Users\jedam\AppData\Local\Temp\ipykernel_17372\3176122859.py:42: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=WEBDRIVER_PATH, options=options)
# WebDriver iniciado.
# Consultando registro (original index 3540): Tipo=CC, Num=27211643
# No se pudo determinar el resultado (ni alerta, ni elemento de éxito/fracaso encontrado en tiempo).
# Resultado: Error: Resultado Indeterminado
# Error al guardar el progreso: [Errno 13] Permission denied: 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3540.xlsx'
# Esperando 1.99 segundos...
# Consultando registro (original index 3541): Tipo=CC, Num=1088654270
# Resultado: No Registrado , no tiene sisben
# Esperando 2.68 segundos...
# Consultando registro (original index 3542): Tipo=CC, Num=1088653608
# Resultado: No Registrado , no tiene sisben
# Esperando 2.69 segundos...
# Consultando registro (original index 3543): Tipo=CC, Num=27215470
# Resultado: No Registrado , no tiene sisben
# Esperando 2.18 segundos...
# Consultando registro (original index 3544): Tipo=CC, Num=1192774527
# Resultado: No Registrado , no tiene sisben
# Esperando 3.71 segundos...
# Consultando registro (original index 3545): Tipo=CC, Num=98342257
# Resultado: No Registrado , no tiene sisben
# Esperando 1.26 segundos...
# Consultando registro (original index 3546): Tipo=CC, Num=1004691794
# Resultado: No Registrado , no tiene sisben
# Esperando 1.92 segundos...
# Consultando registro (original index 3547): Tipo=CC, Num=5253645
# Resultado: No Registrado , no tiene sisben
# Esperando 3.73 segundos...
# Consultando registro (original index 3548): Tipo=CC, Num=27210415
# Resultado: No Registrado , no tiene sisben
# Esperando 3.60 segundos...
# Consultando registro (original index 3549): Tipo=CC, Num=1088650595
# Resultado: No Registrado , no tiene sisben
# Esperando 3.98 segundos...
# Consultando registro (original index 3550): Tipo=CC, Num=13039647
# Resultado: Registrado, persona con sisben
# Esperando 2.31 segundos...
# Consultando registro (original index 3551): Tipo=CC, Num=27211442
# Resultado: No Registrado , no tiene sisben
# Esperando 3.11 segundos...
# Consultando registro (original index 3552): Tipo=CC, Num=1088648179
# Resultado: No Registrado , no tiene sisben
# Esperando 1.72 segundos...
# Consultando registro (original index 3553): Tipo=CC, Num=1192724190
# Resultado: Registrado, persona con sisben
# Esperando 3.78 segundos...
# Consultando registro (original index 3554): Tipo=RC, Num=1088656018
# Resultado: No Registrado , no tiene sisben
# Esperando 1.40 segundos...
# Consultando registro (original index 3555): Tipo=CC, Num=5255896
# Resultado: No Registrado , no tiene sisben
# Esperando 2.35 segundos...
# Consultando registro (original index 3556): Tipo=CC, Num=27210160
# Resultado: No Registrado , no tiene sisben
# Esperando 1.88 segundos...
# Consultando registro (original index 3557): Tipo=CC, Num=1088648342
# Resultado: No Registrado , no tiene sisben
# Esperando 3.28 segundos...
# Consultando registro (original index 3558): Tipo=CC, Num=1088651537
# Resultado: No Registrado , no tiene sisben
# Esperando 3.14 segundos...
# Consultando registro (original index 3559): Tipo=CC, Num=27213995
# Resultado: No Registrado , no tiene sisben
# Esperando 3.95 segundos...
# Consultando registro (original index 3560): Tipo=TI, Num=1088653590
# Resultado: No Registrado , no tiene sisben
# Esperando 2.18 segundos...
# Consultando registro (original index 3561): Tipo=TI, Num=1088654061
# Resultado: No Registrado , no tiene sisben
# Esperando 3.17 segundos...
# Consultando registro (original index 3562): Tipo=CC, Num=1004691675
# Resultado: No Registrado , no tiene sisben
# Esperando 1.66 segundos...
# Consultando registro (original index 3563): Tipo=CC, Num=5255721
# Resultado: No Registrado , no tiene sisben
# Esperando 2.59 segundos...
# Consultando registro (original index 3564): Tipo=CC, Num=5254136
# Resultado: No Registrado , no tiene sisben
# Esperando 1.38 segundos...
# Consultando registro (original index 3565): Tipo=CC, Num=27210368
# Resultado: No Registrado , no tiene sisben
# Esperando 1.65 segundos...
# Consultando registro (original index 3566): Tipo=CC, Num=1127813573
# Resultado: No Registrado , no tiene sisben
# Esperando 3.88 segundos...
# Consultando registro (original index 3567): Tipo=CC, Num=1088648733
# Resultado: No Registrado , no tiene sisben
# Esperando 2.27 segundos...
# Consultando registro (original index 3568): Tipo=CC, Num=1088648848
# Resultado: No Registrado , no tiene sisben
# Esperando 3.90 segundos...
# Consultando registro (original index 3569): Tipo=CC, Num=1088649826
# Resultado: No Registrado , no tiene sisben
# Esperando 1.97 segundos...
# Consultando registro (original index 3570): Tipo=CC, Num=1088648849
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3570.xlsx'
# Esperando 3.86 segundos...
# Consultando registro (original index 3571): Tipo=CC, Num=27175806
# Resultado: No Registrado , no tiene sisben
# Esperando 1.76 segundos...
# Consultando registro (original index 3572): Tipo=CC, Num=27172260
# Resultado: No Registrado , no tiene sisben
# Esperando 1.68 segundos...
# Consultando registro (original index 3573): Tipo=CC, Num=7540025
# Resultado: No Registrado , no tiene sisben
# Esperando 1.36 segundos...
# Consultando registro (original index 3574): Tipo=CC, Num=27211459
# Resultado: No Registrado , no tiene sisben
# Esperando 2.16 segundos...
# Consultando registro (original index 3575): Tipo=CC, Num=5253715
# Resultado: No Registrado , no tiene sisben
# Esperando 1.83 segundos...
# Consultando registro (original index 3576): Tipo=CC, Num=98356442
# Resultado: No Registrado , no tiene sisben
# Esperando 3.12 segundos...
# Consultando registro (original index 3577): Tipo=CC, Num=98342912
# Resultado: No Registrado , no tiene sisben
# Esperando 2.55 segundos...
# Consultando registro (original index 3578): Tipo=CC, Num=1088648329
# Resultado: No Registrado , no tiene sisben
# Esperando 3.08 segundos...
# Consultando registro (original index 3579): Tipo=CC, Num=1085910030
# Resultado: No Registrado , no tiene sisben
# Esperando 2.34 segundos...
# Consultando registro (original index 3580): Tipo=TI, Num=1126142062
# Resultado: No Registrado , no tiene sisben
# Esperando 1.15 segundos...
# Consultando registro (original index 3581): Tipo=CC, Num=1088592098
# Resultado: No Registrado , no tiene sisben
# Esperando 3.59 segundos...
# Consultando registro (original index 3582): Tipo=TI, Num=1088650834
# Resultado: No Registrado , no tiene sisben
# Esperando 3.25 segundos...
# Consultando registro (original index 3583): Tipo=TI, Num=1088653928
# Resultado: No Registrado , no tiene sisben
# Esperando 1.69 segundos...
# Consultando registro (original index 3584): Tipo=CC, Num=1007268476
# Resultado: No Registrado , no tiene sisben
# Esperando 2.49 segundos...
# Consultando registro (original index 3585): Tipo=TI, Num=1085925612
# Resultado: No Registrado , no tiene sisben
# Esperando 3.23 segundos...
# Consultando registro (original index 3586): Tipo=TI, Num=1088594139
# Resultado: No Registrado , no tiene sisben
# Esperando 1.48 segundos...
# Consultando registro (original index 3587): Tipo=TI, Num=1088654458
# Resultado: No Registrado , no tiene sisben
# Esperando 3.65 segundos...
# Consultando registro (original index 3588): Tipo=CC, Num=98342889
# Resultado: No Registrado , no tiene sisben
# Esperando 2.01 segundos...
# Consultando registro (original index 3589): Tipo=CC, Num=1085907530
# Resultado: No Registrado , no tiene sisben
# Esperando 1.26 segundos...
# Consultando registro (original index 3590): Tipo=CC, Num=1088649345
# Resultado: No Registrado , no tiene sisben
# Esperando 2.31 segundos...
# Consultando registro (original index 3591): Tipo=TI, Num=1088652872
# Resultado: No Registrado , no tiene sisben
# Esperando 1.29 segundos...
# Consultando registro (original index 3592): Tipo=CC, Num=1088649585
# Resultado: No Registrado , no tiene sisben
# Esperando 2.62 segundos...
# Consultando registro (original index 3593): Tipo=RC, Num=1088655501
# Resultado: No Registrado , no tiene sisben
# Esperando 3.17 segundos...
# Consultando registro (original index 3594): Tipo=CC, Num=1088650249
# Resultado: No Registrado , no tiene sisben
# Esperando 3.66 segundos...
# Consultando registro (original index 3595): Tipo=TI, Num=1088651909
# Resultado: No Registrado , no tiene sisben
# Esperando 3.84 segundos...
# Consultando registro (original index 3596): Tipo=CC, Num=1088654415
# Resultado: No Registrado , no tiene sisben
# Esperando 2.30 segundos...
# Consultando registro (original index 3597): Tipo=RC, Num=1088655029
# Resultado: No Registrado , no tiene sisben
# Esperando 3.69 segundos...
# Consultando registro (original index 3598): Tipo=CC, Num=1004691467
# Resultado: No Registrado , no tiene sisben
# Esperando 1.15 segundos...
# Consultando registro (original index 3599): Tipo=CC, Num=27212383
# Resultado: No Registrado , no tiene sisben
# Esperando 2.25 segundos...
# Consultando registro (original index 3600): Tipo=TI, Num=1088651944
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3600.xlsx'
# Esperando 2.79 segundos...
# Consultando registro (original index 3601): Tipo=CC, Num=27213245
# Resultado: No Registrado , no tiene sisben
# Esperando 3.14 segundos...
# Consultando registro (original index 3602): Tipo=TI, Num=1088654208
# Resultado: No Registrado , no tiene sisben
# Esperando 2.82 segundos...
# Consultando registro (original index 3603): Tipo=CC, Num=87217886
# Resultado: No Registrado , no tiene sisben
# Esperando 1.65 segundos...
# Consultando registro (original index 3604): Tipo=CC, Num=1088648015
# Resultado: No Registrado , no tiene sisben
# Esperando 1.90 segundos...
# Consultando registro (original index 3605): Tipo=CC, Num=27211851
# Resultado: No Registrado , no tiene sisben
# Esperando 2.37 segundos...
# Consultando registro (original index 3606): Tipo=CC, Num=1085913174
# Resultado: No Registrado , no tiene sisben
# Esperando 3.57 segundos...
# Consultando registro (original index 3607): Tipo=CC, Num=13003800
# Resultado: No Registrado , no tiene sisben
# Esperando 2.54 segundos...
# Consultando registro (original index 3608): Tipo=CC, Num=1088648284
# Resultado: No Registrado , no tiene sisben
# Esperando 1.62 segundos...
# Consultando registro (original index 3609): Tipo=CC, Num=1088654611
# Resultado: No Registrado , no tiene sisben
# Esperando 2.10 segundos...
# Consultando registro (original index 3610): Tipo=CC, Num=5253687
# Resultado: No Registrado , no tiene sisben
# Esperando 1.70 segundos...
# Consultando registro (original index 3611): Tipo=CC, Num=27210128
# Resultado: No Registrado , no tiene sisben
# Esperando 2.45 segundos...
# Consultando registro (original index 3612): Tipo=CC, Num=98356553
# Resultado: No Registrado , no tiene sisben
# Esperando 2.33 segundos...
# Consultando registro (original index 3613): Tipo=CC, Num=37123390
# Resultado: No Registrado , no tiene sisben
# Esperando 3.33 segundos...
# Consultando registro (original index 3614): Tipo=TI, Num=1085941365
# Resultado: No Registrado , no tiene sisben
# Esperando 1.84 segundos...
# Consultando registro (original index 3615): Tipo=CC, Num=1085908174
# Resultado: No Registrado , no tiene sisben
# Esperando 1.93 segundos...
# Consultando registro (original index 3616): Tipo=CC, Num=1088650518
# Resultado: No Registrado , no tiene sisben
# Esperando 2.54 segundos...
# Consultando registro (original index 3617): Tipo=RC, Num=1088655168
# Resultado: No Registrado , no tiene sisben
# Esperando 3.08 segundos...
# Consultando registro (original index 3618): Tipo=CC, Num=5254036
# Resultado: No Registrado , no tiene sisben
# Esperando 3.11 segundos...
# Consultando registro (original index 3619): Tipo=CC, Num=27209557
# Resultado: No Registrado , no tiene sisben
# Esperando 1.59 segundos...
# Consultando registro (original index 3620): Tipo=CC, Num=1088652003
# Resultado: No Registrado , no tiene sisben
# Esperando 3.17 segundos...
# Consultando registro (original index 3621): Tipo=CC, Num=5253146
# Resultado: No Registrado , no tiene sisben
# Esperando 2.86 segundos...
# Consultando registro (original index 3622): Tipo=CC, Num=1085909309
# Resultado: No Registrado , no tiene sisben
# Esperando 1.67 segundos...
# Consultando registro (original index 3623): Tipo=CC, Num=98342042
# Resultado: No Registrado , no tiene sisben
# Esperando 2.57 segundos...
# Consultando registro (original index 3624): Tipo=CC, Num=27211816
# Resultado: No Registrado , no tiene sisben
# Esperando 3.48 segundos...
# Consultando registro (original index 3625): Tipo=CC, Num=1082106142
# Resultado: No Registrado , no tiene sisben
# Esperando 2.97 segundos...
# Consultando registro (original index 3626): Tipo=CC, Num=27212421
# Resultado: No Registrado , no tiene sisben
# Esperando 3.63 segundos...
# Consultando registro (original index 3627): Tipo=CC, Num=98341531
# Resultado: No Registrado , no tiene sisben
# Esperando 1.94 segundos...
# Consultando registro (original index 3628): Tipo=CC, Num=59823465
# Resultado: No Registrado , no tiene sisben
# Esperando 3.38 segundos...
# Consultando registro (original index 3629): Tipo=CC, Num=1080045447
# Resultado: No Registrado , no tiene sisben
# Esperando 1.26 segundos...
# Consultando registro (original index 3630): Tipo=CC, Num=13039775
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3630.xlsx'
# Esperando 3.11 segundos...
# Consultando registro (original index 3631): Tipo=CC, Num=52814471
# Resultado: No Registrado , no tiene sisben
# Esperando 3.35 segundos...
# Consultando registro (original index 3632): Tipo=TI, Num=1020760577
# Resultado: No Registrado , no tiene sisben
# Esperando 1.32 segundos...
# Consultando registro (original index 3633): Tipo=TI, Num=1020835665
# Resultado: No Registrado , no tiene sisben
# Esperando 2.13 segundos...
# Consultando registro (original index 3634): Tipo=RC, Num=1020851134
# Resultado: No Registrado , no tiene sisben
# Esperando 1.06 segundos...
# Consultando registro (original index 3635): Tipo=CC, Num=13074140
# Resultado: Registrado, persona con sisben
# Esperando 1.97 segundos...
# Consultando registro (original index 3636): Tipo=CC, Num=27168478
# Resultado: Registrado, persona con sisben
# Esperando 3.06 segundos...
# Consultando registro (original index 3637): Tipo=CC, Num=1085902263
# Resultado: Registrado, persona con sisben
# Esperando 2.93 segundos...
# Consultando registro (original index 3638): Tipo=CC, Num=1192757475
# Resultado: No Registrado , no tiene sisben
# Esperando 1.41 segundos...
# Consultando registro (original index 3639): Tipo=CC, Num=1088649681
# Resultado: No Registrado , no tiene sisben
# Esperando 2.59 segundos...
# Consultando registro (original index 3640): Tipo=CC, Num=1088651830
# Resultado: No Registrado , no tiene sisben
# Esperando 2.52 segundos...
# Consultando registro (original index 3641): Tipo=CC, Num=98341648
# Resultado: No Registrado , no tiene sisben
# Esperando 3.03 segundos...
# Consultando registro (original index 3642): Tipo=CC, Num=27211789
# Resultado: No Registrado , no tiene sisben
# Esperando 3.01 segundos...
# Consultando registro (original index 3643): Tipo=CC, Num=1088653226
# Resultado: No Registrado , no tiene sisben
# Esperando 3.91 segundos...
# Consultando registro (original index 3644): Tipo=CC, Num=1085899751
# Resultado: No Registrado , no tiene sisben
# Esperando 3.65 segundos...
# Consultando registro (original index 3645): Tipo=CC, Num=1130678481
# Resultado: No Registrado , no tiene sisben
# Esperando 2.81 segundos...
# Consultando registro (original index 3646): Tipo=RC, Num=1088655260
# Resultado: No Registrado , no tiene sisben
# Esperando 2.86 segundos...
# Consultando registro (original index 3647): Tipo=CC, Num=1088652968
# Resultado: No Registrado , no tiene sisben
# Esperando 3.72 segundos...
# Consultando registro (original index 3648): Tipo=CC, Num=13039915
# Resultado: No Registrado , no tiene sisben
# Esperando 2.26 segundos...
# Consultando registro (original index 3649): Tipo=CC, Num=27210880
# Resultado: No Registrado , no tiene sisben
# Esperando 2.31 segundos...
# Consultando registro (original index 3650): Tipo=CC, Num=1004691635
# Resultado: No Registrado , no tiene sisben
# Esperando 2.70 segundos...
# Consultando registro (original index 3651): Tipo=CC, Num=1088652962
# Resultado: No Registrado , no tiene sisben
# Esperando 1.82 segundos...
# Consultando registro (original index 3652): Tipo=TI, Num=1055710751
# Resultado: No Registrado , no tiene sisben
# Esperando 3.38 segundos...
# Consultando registro (original index 3653): Tipo=CC, Num=27332226
# Resultado: No Registrado , no tiene sisben
# Esperando 3.65 segundos...
# Consultando registro (original index 3654): Tipo=CC, Num=1004550520
# Resultado: No Registrado , no tiene sisben
# Esperando 3.15 segundos...
# Consultando registro (original index 3655): Tipo=CC, Num=1004692143
# Resultado: No Registrado , no tiene sisben
# Esperando 3.53 segundos...
# Consultando registro (original index 3656): Tipo=TI, Num=1088654534
# Resultado: No Registrado , no tiene sisben
# Esperando 3.24 segundos...
# Consultando registro (original index 3657): Tipo=CC, Num=27212211
# Resultado: No Registrado , no tiene sisben
# Esperando 2.79 segundos...
# Consultando registro (original index 3658): Tipo=TI , Num=1088652163
# Resultado: No Registrado , no tiene sisben
# Esperando 3.67 segundos...
# Consultando registro (original index 3659): Tipo=CC, Num=13039232
# Resultado: Registrado, persona con sisben
# Esperando 1.40 segundos...
# Consultando registro (original index 3660): Tipo=CC, Num=27212023
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3660.xlsx'
# Esperando 3.14 segundos...
# Consultando registro (original index 3661): Tipo=TI, Num=1144826083
# Resultado: No Registrado , no tiene sisben
# Esperando 1.55 segundos...
# Consultando registro (original index 3662): Tipo=CC, Num=98341287
# Resultado: No Registrado , no tiene sisben
# Esperando 2.69 segundos...
# Consultando registro (original index 3663): Tipo=CC, Num=27212719
# Resultado: No Registrado , no tiene sisben
# Esperando 2.91 segundos...
# Consultando registro (original index 3664): Tipo=CC, Num=98341915
# Resultado: No Registrado , no tiene sisben
# Esperando 1.34 segundos...
# Consultando registro (original index 3665): Tipo=CC, Num=59178697
# Resultado: No Registrado , no tiene sisben
# Esperando 1.28 segundos...
# Consultando registro (original index 3666): Tipo=TI, Num=1088652100
# Resultado: No Registrado , no tiene sisben
# Esperando 2.68 segundos...
# Consultando registro (original index 3667): Tipo=CC, Num=5254298
# Resultado: No Registrado , no tiene sisben
# Esperando 2.14 segundos...
# Consultando registro (original index 3668): Tipo=CC, Num=27210896
# Resultado: No Registrado , no tiene sisben
# Esperando 3.97 segundos...
# Consultando registro (original index 3669): Tipo=CC, Num=1004691654
# Resultado: No Registrado , no tiene sisben
# Esperando 3.76 segundos...
# Consultando registro (original index 3670): Tipo=RC, Num=1088655244
# Resultado: No Registrado , no tiene sisben
# Esperando 1.28 segundos...
# Consultando registro (original index 3671): Tipo=CC, Num=27213469
# Resultado: No Registrado , no tiene sisben
# Esperando 3.39 segundos...
# Consultando registro (original index 3672): Tipo=CC, Num=1004692063
# Resultado: No Registrado , no tiene sisben
# Esperando 2.72 segundos...
# Consultando registro (original index 3673): Tipo=CC, Num=5253993
# Resultado: No Registrado , no tiene sisben
# Esperando 2.57 segundos...
# Consultando registro (original index 3674): Tipo=CC, Num=27211498
# Resultado: No Registrado , no tiene sisben
# Esperando 2.66 segundos...
# Consultando registro (original index 3675): Tipo=CC, Num=1088651464
# Resultado: No Registrado , no tiene sisben
# Esperando 1.97 segundos...
# Consultando registro (original index 3676): Tipo=CC, Num=1088653035
# Resultado: No Registrado , no tiene sisben
# Esperando 1.12 segundos...
# Consultando registro (original index 3677): Tipo=CC, Num=13039792
# Resultado: No Registrado , no tiene sisben
# Esperando 3.79 segundos...
# Consultando registro (original index 3678): Tipo=CC, Num=1088648825
# Resultado: No Registrado , no tiene sisben
# Esperando 2.20 segundos...
# Consultando registro (original index 3679): Tipo=RC, Num=1088655307
# Resultado: No Registrado , no tiene sisben
# Esperando 2.08 segundos...
# Consultando registro (original index 3680): Tipo=CC, Num=1192804395
# Resultado: No Registrado , no tiene sisben
# Esperando 2.17 segundos...
# Consultando registro (original index 3681): Tipo=CC, Num=98383244
# Resultado: No Registrado , no tiene sisben
# Esperando 2.43 segundos...
# Consultando registro (original index 3682): Tipo=CC, Num=27105306
# Resultado: No Registrado , no tiene sisben
# Esperando 2.95 segundos...
# Consultando registro (original index 3683): Tipo=CC, Num=27210917
# Resultado: No Registrado , no tiene sisben
# Esperando 1.10 segundos...
# Consultando registro (original index 3684): Tipo=TI, Num=1144824525
# Resultado: No Registrado , no tiene sisben
# Esperando 2.74 segundos...
# Consultando registro (original index 3685): Tipo=CC, Num=13039754
# Resultado: No Registrado , no tiene sisben
# Esperando 3.18 segundos...
# Consultando registro (original index 3686): Tipo=CC, Num=1192775200
# Resultado: No Registrado , no tiene sisben
# Esperando 3.28 segundos...
# Consultando registro (original index 3687): Tipo=CC, Num=13039419
# Resultado: No Registrado , no tiene sisben
# Esperando 2.93 segundos...
# Consultando registro (original index 3688): Tipo=CC, Num=98356452
# Resultado: No Registrado , no tiene sisben
# Esperando 3.43 segundos...
# Consultando registro (original index 3689): Tipo=CC, Num=27211795
# Resultado: No Registrado , no tiene sisben
# Esperando 1.60 segundos...
# Consultando registro (original index 3690): Tipo=CC, Num=1085903670
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3690.xlsx'
# Esperando 2.61 segundos...
# Consultando registro (original index 3691): Tipo=CC, Num=37000366
# Resultado: No Registrado , no tiene sisben
# Esperando 2.78 segundos...
# Consultando registro (original index 3692): Tipo=CC, Num=98342867
# Resultado: No Registrado , no tiene sisben
# Esperando 1.20 segundos...
# Consultando registro (original index 3693): Tipo=CC, Num=1088649384
# Resultado: No Registrado , no tiene sisben
# Esperando 1.32 segundos...
# Consultando registro (original index 3694): Tipo=CC, Num=1004692125
# Resultado: No Registrado , no tiene sisben
# Esperando 2.10 segundos...
# Consultando registro (original index 3695): Tipo=CC, Num=1088649962
# Resultado: No Registrado , no tiene sisben
# Esperando 3.80 segundos...
# Consultando registro (original index 3696): Tipo=RC, Num=1088654197
# Resultado: No Registrado , no tiene sisben
# Esperando 1.54 segundos...
# Consultando registro (original index 3697): Tipo=CC, Num=98385619
# Resultado: No Registrado , no tiene sisben
# Esperando 2.68 segundos...
# Consultando registro (original index 3698): Tipo=CC, Num=27210385
# Resultado: No Registrado , no tiene sisben
# Esperando 2.74 segundos...
# Consultando registro (original index 3699): Tipo=CC, Num=1004691915
# Resultado: No Registrado , no tiene sisben
# Esperando 3.62 segundos...
# Consultando registro (original index 3700): Tipo=CC, Num=27212149
# Resultado: No Registrado , no tiene sisben
# Esperando 1.20 segundos...
# Consultando registro (original index 3701): Tipo=CC, Num=1192890050
# Resultado: No Registrado , no tiene sisben
# Esperando 1.32 segundos...
# Consultando registro (original index 3702): Tipo=CC, Num=1004534903
# Resultado: No Registrado , no tiene sisben
# Esperando 3.25 segundos...
# Consultando registro (original index 3703): Tipo=CC, Num=5254331
# Resultado: No Registrado , no tiene sisben
# Esperando 2.75 segundos...
# Consultando registro (original index 3704): Tipo=CC, Num=27209789
# Resultado: No Registrado , no tiene sisben
# Esperando 3.55 segundos...
# Consultando registro (original index 3705): Tipo=CC, Num=1088650210
# Resultado: No Registrado , no tiene sisben
# Esperando 2.61 segundos...
# Consultando registro (original index 3706): Tipo=CC, Num=37083586
# Resultado: No Registrado , no tiene sisben
# Esperando 3.94 segundos...
# Consultando registro (original index 3707): Tipo=CC, Num=1085320880
# Resultado: No Registrado , no tiene sisben
# Esperando 1.71 segundos...
# Consultando registro (original index 3708): Tipo=CC, Num=1080046730
# Resultado: No Registrado , no tiene sisben
# Esperando 3.92 segundos...
# Consultando registro (original index 3709): Tipo=CC, Num=5254962
# Resultado: No Registrado , no tiene sisben
# Esperando 3.62 segundos...
# Consultando registro (original index 3710): Tipo=CC, Num=27212041
# Resultado: No Registrado , no tiene sisben
# Esperando 1.11 segundos...
# Consultando registro (original index 3711): Tipo=TI, Num=1088654461
# Resultado: No Registrado , no tiene sisben
# Esperando 3.26 segundos...
# Consultando registro (original index 3712): Tipo=RC, Num=1088655377
# Resultado: No Registrado , no tiene sisben
# Esperando 2.25 segundos...
# Consultando registro (original index 3713): Tipo=CC, Num=1192804335
# Resultado: No Registrado , no tiene sisben
# Esperando 2.39 segundos...
# Consultando registro (original index 3714): Tipo=CC, Num=27210688
# Resultado: No Registrado , no tiene sisben
# Esperando 3.95 segundos...
# Consultando registro (original index 3715): Tipo=CC, Num=1088648869
# Resultado: No Registrado , no tiene sisben
# Esperando 2.84 segundos...
# Consultando registro (original index 3716): Tipo=CC, Num=1085911854
# Resultado: No Registrado , no tiene sisben
# Esperando 2.63 segundos...
# Consultando registro (original index 3717): Tipo=RC, Num=1088655533
# Resultado: No Registrado , no tiene sisben
# Esperando 3.72 segundos...
# Consultando registro (original index 3718): Tipo=CC, Num=13065805
# Resultado: No Registrado , no tiene sisben
# Esperando 1.29 segundos...
# Consultando registro (original index 3719): Tipo=CC, Num=5268638
# Resultado: No Registrado , no tiene sisben
# Esperando 1.29 segundos...
# Consultando registro (original index 3720): Tipo=CC, Num=1088654175
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3720.xlsx'
# Esperando 3.31 segundos...
# Consultando registro (original index 3721): Tipo=TI, Num=1088653926
# Resultado: No Registrado , no tiene sisben
# Esperando 1.06 segundos...
# Consultando registro (original index 3722): Tipo=RC, Num=1088655418
# Resultado: No Registrado , no tiene sisben
# Esperando 3.97 segundos...
# Consultando registro (original index 3723): Tipo=CC, Num=27213400
# Resultado: No Registrado , no tiene sisben
# Esperando 1.78 segundos...
# Consultando registro (original index 3724): Tipo=CC, Num=27212156
# Resultado: Registrado, persona con sisben
# Esperando 3.68 segundos...
# Consultando registro (original index 3725): Tipo=CC, Num=1004533921
# Resultado: Registrado, persona con sisben
# Esperando 2.52 segundos...
# Consultando registro (original index 3726): Tipo=TI, Num=1085918889
# Resultado: Registrado, persona con sisben
# Esperando 1.32 segundos...
# Consultando registro (original index 3727): Tipo=CC, Num=1085911319
# Resultado: No Registrado , no tiene sisben
# Esperando 2.16 segundos...
# Consultando registro (original index 3728): Tipo=CC, Num=27214096
# Resultado: No Registrado , no tiene sisben
# Esperando 3.73 segundos...
# Consultando registro (original index 3729): Tipo=CC, Num=1088651152
# Resultado: No Registrado , no tiene sisben
# Esperando 2.22 segundos...
# Consultando registro (original index 3730): Tipo=CC, Num=27105542
# Resultado: No Registrado , no tiene sisben
# Esperando 3.05 segundos...
# Consultando registro (original index 3731): Tipo=TI, Num=1088653246
# Resultado: No Registrado , no tiene sisben
# Esperando 3.65 segundos...
# Consultando registro (original index 3732): Tipo=CC, Num=1088648958
# Resultado: No Registrado , no tiene sisben
# Esperando 3.52 segundos...
# Consultando registro (original index 3733): Tipo=CC, Num=13039242
# Resultado: No Registrado , no tiene sisben
# Esperando 3.97 segundos...
# Consultando registro (original index 3734): Tipo=CC, Num=1004691775
# Resultado: No Registrado , no tiene sisben
# Esperando 2.35 segundos...
# Consultando registro (original index 3735): Tipo=CC, Num=5255424
# Resultado: No Registrado , no tiene sisben
# Esperando 2.79 segundos...
# Consultando registro (original index 3736): Tipo=CC, Num=1086578085
# Resultado: No Registrado , no tiene sisben
# Esperando 3.60 segundos...
# Consultando registro (original index 3737): Tipo=CC, Num=1088648526
# Resultado: No Registrado , no tiene sisben
# Esperando 3.68 segundos...
# Consultando registro (original index 3738): Tipo=CC, Num=5254851
# Resultado: No Registrado , no tiene sisben
# Esperando 1.41 segundos...
# Consultando registro (original index 3739): Tipo=TI, Num=1088651934
# Resultado: No Registrado , no tiene sisben
# Esperando 2.97 segundos...
# Consultando registro (original index 3740): Tipo=CC, Num=1004691928
# Resultado: No Registrado , no tiene sisben
# Esperando 3.40 segundos...
# Consultando registro (original index 3741): Tipo=TI, Num=1088653872
# Resultado: No Registrado , no tiene sisben
# Esperando 2.14 segundos...
# Consultando registro (original index 3742): Tipo=CC, Num=1085906230
# Resultado: No Registrado , no tiene sisben
# Esperando 3.45 segundos...
# Consultando registro (original index 3743): Tipo=CC, Num=1085902817
# Resultado: No Registrado , no tiene sisben
# Esperando 2.79 segundos...
# Consultando registro (original index 3744): Tipo=TI, Num=1088653070
# Resultado: No Registrado , no tiene sisben
# Esperando 2.49 segundos...
# Consultando registro (original index 3745): Tipo=CC, Num=1088650153
# Resultado: No Registrado , no tiene sisben
# Esperando 3.49 segundos...
# Consultando registro (original index 3746): Tipo=CC, Num=1088650238
# Resultado: No Registrado , no tiene sisben
# Esperando 3.40 segundos...
# Consultando registro (original index 3747): Tipo=TI, Num=1088650654
# Resultado: No Registrado , no tiene sisben
# Esperando 1.40 segundos...
# Consultando registro (original index 3748): Tipo=TI, Num=1088651827
# Resultado: No Registrado , no tiene sisben
# Esperando 3.39 segundos...
# Consultando registro (original index 3749): Tipo=CC, Num=12978082
# Resultado: No Registrado , no tiene sisben
# Esperando 1.85 segundos...
# Consultando registro (original index 3750): Tipo=CC, Num=27211385
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3750.xlsx'
# Esperando 1.65 segundos...
# Consultando registro (original index 3751): Tipo=CC, Num=98342210
# Resultado: No Registrado , no tiene sisben
# Esperando 1.50 segundos...
# Consultando registro (original index 3752): Tipo=CC, Num=27212454
# Resultado: No Registrado , no tiene sisben
# Esperando 3.40 segundos...
# Consultando registro (original index 3753): Tipo=CC, Num=1004692252
# Resultado: No Registrado , no tiene sisben
# Esperando 1.83 segundos...
# Consultando registro (original index 3754): Tipo=CC, Num=1004692288
# Resultado: No Registrado , no tiene sisben
# Esperando 4.00 segundos...
# Consultando registro (original index 3755): Tipo=CC, Num=1088648384
# Resultado: No Registrado , no tiene sisben
# Esperando 2.39 segundos...
# Consultando registro (original index 3756): Tipo=CC, Num=5254993
# Resultado: No Registrado , no tiene sisben
# Esperando 3.35 segundos...
# Consultando registro (original index 3757): Tipo=TI, Num=1088652983
# Resultado: No Registrado , no tiene sisben
# Esperando 1.67 segundos...
# Consultando registro (original index 3758): Tipo=CC, Num=27209801
# Resultado: No Registrado , no tiene sisben
# Esperando 3.58 segundos...
# Consultando registro (original index 3759): Tipo=CC, Num=1088651858
# Resultado: No Registrado , no tiene sisben
# Esperando 2.24 segundos...
# Consultando registro (original index 3760): Tipo=CC, Num=5253799
# Resultado: No Registrado , no tiene sisben
# Esperando 2.59 segundos...
# Consultando registro (original index 3761): Tipo=CC, Num=27209983
# Resultado: No Registrado , no tiene sisben
# Esperando 4.00 segundos...
# Consultando registro (original index 3762): Tipo=CC, Num=1004695109
# Resultado: No Registrado , no tiene sisben
# Esperando 3.98 segundos...
# Consultando registro (original index 3763): Tipo=CC, Num=1088650114
# Resultado: No Registrado , no tiene sisben
# Esperando 1.48 segundos...
# Consultando registro (original index 3764): Tipo=CC, Num=1088653720
# Resultado: No Registrado , no tiene sisben
# Esperando 2.31 segundos...
# Consultando registro (original index 3765): Tipo=CC, Num=98341889
# Resultado: No Registrado , no tiene sisben
# Esperando 1.51 segundos...
# Consultando registro (original index 3766): Tipo=CC, Num=5254331
# Resultado: No Registrado , no tiene sisben
# Esperando 1.20 segundos...
# Consultando registro (original index 3767): Tipo=CC, Num=27209789
# Resultado: No Registrado , no tiene sisben
# Esperando 2.02 segundos...
# Consultando registro (original index 3768): Tipo=CC, Num=1088650210
# Resultado: No Registrado , no tiene sisben
# Esperando 1.28 segundos...
# Consultando registro (original index 3769): Tipo=CC, Num=13039522
# Resultado: No Registrado , no tiene sisben
# Esperando 3.07 segundos...
# Consultando registro (original index 3770): Tipo=CC, Num=27213976
# Resultado: No Registrado , no tiene sisben
# Esperando 3.74 segundos...
# Consultando registro (original index 3771): Tipo=TI, Num=1088651779
# Resultado: No Registrado , no tiene sisben
# Esperando 1.69 segundos...
# Consultando registro (original index 3772): Tipo=CC, Num=1088649077
# Resultado: No Registrado , no tiene sisben
# Esperando 1.56 segundos...
# Consultando registro (original index 3773): Tipo=CC, Num=27210244
# Resultado: No Registrado , no tiene sisben
# Esperando 3.85 segundos...
# Consultando registro (original index 3774): Tipo=CC, Num=1088653014
# Resultado: No Registrado , no tiene sisben
# Esperando 2.44 segundos...
# Consultando registro (original index 3775): Tipo=CC, Num=5291837
# Resultado: No Registrado , no tiene sisben
# Esperando 2.57 segundos...
# Consultando registro (original index 3776): Tipo=CC, Num=27209065
# Resultado: No Registrado , no tiene sisben
# Esperando 2.20 segundos...
# Consultando registro (original index 3777): Tipo=CC, Num=5254300
# Resultado: No Registrado , no tiene sisben
# Esperando 2.18 segundos...
# Consultando registro (original index 3778): Tipo=CC, Num=5253967
# Resultado: No Registrado , no tiene sisben
# Esperando 3.18 segundos...
# Consultando registro (original index 3779): Tipo=CC, Num=5254843
# Resultado: No Registrado , no tiene sisben
# Esperando 2.22 segundos...
# Consultando registro (original index 3780): Tipo=CC, Num=27213017
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3780.xlsx'
# Esperando 3.02 segundos...
# Consultando registro (original index 3781): Tipo=CC, Num=1004691858
# Resultado: No Registrado , no tiene sisben
# Esperando 3.69 segundos...
# Consultando registro (original index 3782): Tipo=CC, Num=27209049
# Resultado: No Registrado , no tiene sisben
# Esperando 2.01 segundos...
# Consultando registro (original index 3783): Tipo=CC, Num=27211234
# Resultado: No Registrado , no tiene sisben
# Esperando 1.09 segundos...
# Consultando registro (original index 3784): Tipo=CC, Num=98342032
# Resultado: No Registrado , no tiene sisben
# Esperando 3.42 segundos...
# Consultando registro (original index 3785): Tipo=CC, Num=27213420
# Resultado: No Registrado , no tiene sisben
# Esperando 3.67 segundos...
# Consultando registro (original index 3786): Tipo=RC, Num=1088655077
# Resultado: No Registrado , no tiene sisben
# Esperando 2.34 segundos...
# Consultando registro (original index 3787): Tipo=CC, Num=27213294
# Resultado: No Registrado , no tiene sisben
# Esperando 2.11 segundos...
# Consultando registro (original index 3788): Tipo=TI, Num=1085924325
# Resultado: No Registrado , no tiene sisben
# Esperando 1.79 segundos...
# Consultando registro (original index 3789): Tipo=CC, Num=27210628
# Resultado: No Registrado , no tiene sisben
# Esperando 3.48 segundos...
# Consultando registro (original index 3790): Tipo=CC, Num=27213089
# Resultado: No Registrado , no tiene sisben
# Esperando 2.63 segundos...
# Consultando registro (original index 3791): Tipo=CC, Num=1088651255
# Resultado: No Registrado , no tiene sisben
# Esperando 1.96 segundos...
# Consultando registro (original index 3792): Tipo=CC, Num=13039323
# Resultado: No Registrado , no tiene sisben
# Esperando 2.63 segundos...
# Consultando registro (original index 3793): Tipo=CC, Num=25215709
# Resultado: No Registrado , no tiene sisben
# Esperando 2.80 segundos...
# Consultando registro (original index 3794): Tipo=TI, Num=1144824598
# Resultado: No Registrado , no tiene sisben
# Esperando 2.00 segundos...
# Consultando registro (original index 3795): Tipo=CC, Num=1060586089
# Resultado: No Registrado , no tiene sisben
# Esperando 2.91 segundos...
# Consultando registro (original index 3796): Tipo=CC, Num=1864831
# Resultado: No Registrado , no tiene sisben
# Esperando 3.03 segundos...
# Consultando registro (original index 3797): Tipo=CC, Num=27209051
# Resultado: No Registrado , no tiene sisben
# Esperando 2.00 segundos...
# Consultando registro (original index 3798): Tipo=CC, Num=1088648826
# Resultado: No Registrado , no tiene sisben
# Esperando 2.49 segundos...
# Consultando registro (original index 3799): Tipo=CC, Num=27212157
# Resultado: Registrado, persona con sisben
# Esperando 2.05 segundos...
# Consultando registro (original index 3800): Tipo=CC, Num=27208799
# Resultado: No Registrado , no tiene sisben
# Esperando 3.97 segundos...
# Consultando registro (original index 3801): Tipo=CC, Num=1082104280
# Resultado: No Registrado , no tiene sisben
# Esperando 1.95 segundos...
# Consultando registro (original index 3802): Tipo=CC, Num=1088649896
# Resultado: No Registrado , no tiene sisben
# Esperando 2.36 segundos...
# Consultando registro (original index 3803): Tipo=CC, Num=27486626
# Resultado: No Registrado , no tiene sisben
# Esperando 2.26 segundos...
# Consultando registro (original index 3804): Tipo=TI, Num=1088653308
# Resultado: No Registrado , no tiene sisben
# Esperando 3.14 segundos...
# Consultando registro (original index 3805): Tipo=CC, Num=5253422
# Resultado: No Registrado , no tiene sisben
# Esperando 1.69 segundos...
# Consultando registro (original index 3806): Tipo=CC, Num=98341567
# Resultado: No Registrado , no tiene sisben
# Esperando 2.66 segundos...
# Consultando registro (original index 3807): Tipo=CC, Num=27210718
# Resultado: No Registrado , no tiene sisben
# Esperando 3.70 segundos...
# Consultando registro (original index 3808): Tipo=CC, Num=1088652830
# Resultado: No Registrado , no tiene sisben
# Esperando 3.29 segundos...
# Consultando registro (original index 3809): Tipo=CC, Num=1004692303
# Resultado: No Registrado , no tiene sisben
# Esperando 1.06 segundos...
# Consultando registro (original index 3810): Tipo=TI, Num=1088654653
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3810.xlsx'
# Esperando 2.25 segundos...
# Consultando registro (original index 3811): Tipo=CC, Num=98341651
# Resultado: No Registrado , no tiene sisben
# Esperando 2.22 segundos...
# Consultando registro (original index 3812): Tipo=CC, Num=27211144
# Resultado: No Registrado , no tiene sisben
# Esperando 1.79 segundos...
# Consultando registro (original index 3813): Tipo=CC, Num=1088654074
# Resultado: No Registrado , no tiene sisben
# Esperando 3.22 segundos...
# Consultando registro (original index 3814): Tipo=CC, Num=13039608
# Resultado: Registrado, persona con sisben
# Esperando 3.43 segundos...
# Consultando registro (original index 3815): Tipo=CC, Num=13039755
# Resultado: No Registrado , no tiene sisben
# Esperando 3.96 segundos...
# Consultando registro (original index 3816): Tipo=CC, Num=27213064
# Resultado: No Registrado , no tiene sisben
# Esperando 2.09 segundos...
# Consultando registro (original index 3817): Tipo=TI, Num=1088652684
# Resultado: No Registrado , no tiene sisben
# Esperando 1.19 segundos...
# Consultando registro (original index 3818): Tipo=CC, Num=1088648905
# Resultado: No Registrado , no tiene sisben
# Esperando 1.09 segundos...
# Consultando registro (original index 3819): Tipo=CC, Num=27209930
# Resultado: No Registrado , no tiene sisben
# Esperando 3.49 segundos...
# Consultando registro (original index 3820): Tipo=CC, Num=5254852
# Resultado: No Registrado , no tiene sisben
# Esperando 1.11 segundos...
# Consultando registro (original index 3821): Tipo=CC, Num=27213016
# Resultado: No Registrado , no tiene sisben
# Esperando 2.91 segundos...
# Consultando registro (original index 3822): Tipo=TI, Num=1088650665
# Resultado: No Registrado , no tiene sisben
# Esperando 1.24 segundos...
# Consultando registro (original index 3823): Tipo=CC, Num=1192757477
# Resultado: No Registrado , no tiene sisben
# Esperando 1.17 segundos...
# Consultando registro (original index 3824): Tipo=CC, Num=27210702
# Resultado: No Registrado , no tiene sisben
# Esperando 3.23 segundos...
# Consultando registro (original index 3825): Tipo=CC, Num=1088590227
# Resultado: No Registrado , no tiene sisben
# Esperando 2.26 segundos...
# Consultando registro (original index 3826): Tipo=CC, Num=27211707
# Resultado: No Registrado , no tiene sisben
# Esperando 3.41 segundos...
# Consultando registro (original index 3827): Tipo=CC, Num=1004691949
# Resultado: No Registrado , no tiene sisben
# Esperando 3.28 segundos...
# Consultando registro (original index 3828): Tipo=CC, Num=1088648626
# Resultado: No Registrado , no tiene sisben
# Esperando 1.02 segundos...
# Consultando registro (original index 3829): Tipo=CC, Num=1088648857
# Resultado: No Registrado , no tiene sisben
# Esperando 1.72 segundos...
# Consultando registro (original index 3830): Tipo=CC, Num=1081053812
# Resultado: No Registrado , no tiene sisben
# Esperando 1.95 segundos...
# Consultando registro (original index 3831): Tipo=CC, Num=27211842
# Resultado: No Registrado , no tiene sisben
# Esperando 1.65 segundos...
# Consultando registro (original index 3832): Tipo=CC, Num=1088651032
# Resultado: No Registrado , no tiene sisben
# Esperando 2.19 segundos...
# Consultando registro (original index 3833): Tipo=RC, Num=1088655024
# Resultado: No Registrado , no tiene sisben
# Esperando 2.28 segundos...
# Consultando registro (original index 3834): Tipo=CC, Num=98341633
# Resultado: No Registrado , no tiene sisben
# Esperando 1.16 segundos...
# Consultando registro (original index 3835): Tipo=CC, Num=27211333
# Resultado: No Registrado , no tiene sisben
# Esperando 2.28 segundos...
# Consultando registro (original index 3836): Tipo=CC, Num=1088651361
# Resultado: No Registrado , no tiene sisben
# Esperando 3.33 segundos...
# Consultando registro (original index 3837): Tipo=CC, Num=1088654022
# Resultado: No Registrado , no tiene sisben
# Esperando 3.79 segundos...
# Consultando registro (original index 3838): Tipo=CC, Num=1088651913
# Resultado: No Registrado , no tiene sisben
# Esperando 3.08 segundos...
# Consultando registro (original index 3839): Tipo=CC, Num=27213273
# Resultado: No Registrado , no tiene sisben
# Esperando 3.40 segundos...
# Consultando registro (original index 3840): Tipo=TI, Num=1081278477
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3840.xlsx'
# Esperando 2.98 segundos...
# Consultando registro (original index 3841): Tipo=CC, Num=27210432
# Resultado: No Registrado , no tiene sisben
# Esperando 2.97 segundos...
# Consultando registro (original index 3842): Tipo=CC, Num=1088650591
# Resultado: No Registrado , no tiene sisben
# Esperando 3.77 segundos...
# Consultando registro (original index 3843): Tipo=CC, Num=27210720
# Resultado: No Registrado , no tiene sisben
# Esperando 1.22 segundos...
# Consultando registro (original index 3844): Tipo=CC, Num=1085278854
# Resultado: No Registrado , no tiene sisben
# Esperando 2.12 segundos...
# Consultando registro (original index 3845): Tipo=CC, Num=1047407348
# Resultado: No Registrado , no tiene sisben
# Esperando 2.66 segundos...
# Consultando registro (original index 3846): Tipo=CC, Num=1088651076
# Resultado: No Registrado , no tiene sisben
# Esperando 1.96 segundos...
# Consultando registro (original index 3847): Tipo=CC, Num=98341365
# Resultado: No Registrado , no tiene sisben
# Esperando 3.29 segundos...
# Consultando registro (original index 3848): Tipo=CC, Num=27214074
# Resultado: No Registrado , no tiene sisben
# Esperando 2.29 segundos...
# Consultando registro (original index 3849): Tipo=TI, Num=27214074
# Resultado: No Registrado , no tiene sisben
# Esperando 2.98 segundos...
# Consultando registro (original index 3850): Tipo=CC, Num=5254041
# Resultado: No Registrado , no tiene sisben
# Esperando 3.54 segundos...
# Consultando registro (original index 3851): Tipo=CC, Num=27209965
# Resultado: No Registrado , no tiene sisben
# Esperando 1.03 segundos...
# Consultando registro (original index 3852): Tipo=CC, Num=27249766
# Resultado: No Registrado , no tiene sisben
# Esperando 1.67 segundos...
# Consultando registro (original index 3853): Tipo=CC, Num=27209544
# Resultado: No Registrado , no tiene sisben
# Esperando 2.90 segundos...
# Consultando registro (original index 3854): Tipo=CC, Num=1088649966
# Resultado: No Registrado , no tiene sisben
# Esperando 3.63 segundos...
# Consultando registro (original index 3855): Tipo=TI , Num=1085930491
# Resultado: No Registrado , no tiene sisben
# Esperando 3.10 segundos...
# Consultando registro (original index 3856): Tipo=TI, Num=1088652664
# Resultado: No Registrado , no tiene sisben
# Esperando 2.34 segundos...
# Consultando registro (original index 3857): Tipo=CC, Num=5254068
# Resultado: No Registrado , no tiene sisben
# Esperando 2.94 segundos...
# Consultando registro (original index 3858): Tipo=CC, Num=13039264
# Resultado: Registrado, persona con sisben
# Esperando 1.69 segundos...
# Consultando registro (original index 3859): Tipo=CC, Num=27212362
# Resultado: No Registrado , no tiene sisben
# Esperando 2.49 segundos...
# Consultando registro (original index 3860): Tipo=TI, Num=1085942073
# Resultado: No Registrado , no tiene sisben
# Esperando 2.81 segundos...
# Consultando registro (original index 3861): Tipo=CC, Num=5253050
# Resultado: No Registrado , no tiene sisben
# Esperando 1.42 segundos...
# Consultando registro (original index 3862): Tipo=CC, Num=27208838
# Resultado: No Registrado , no tiene sisben
# Esperando 3.23 segundos...
# Consultando registro (original index 3863): Tipo=CC, Num=27212921
# Resultado: No Registrado , no tiene sisben
# Esperando 4.00 segundos...
# Consultando registro (original index 3864): Tipo=CC, Num=5254759
# Resultado: No Registrado , no tiene sisben
# Esperando 3.21 segundos...
# Consultando registro (original index 3865): Tipo=CC, Num=27213109
# Resultado: No Registrado , no tiene sisben
# Esperando 1.66 segundos...
# Consultando registro (original index 3866): Tipo=TI , Num=1088653727
# Resultado: No Registrado , no tiene sisben
# Esperando 3.41 segundos...
# Consultando registro (original index 3867): Tipo=CC, Num=1004692088
# Resultado: No Registrado , no tiene sisben
# Esperando 2.02 segundos...
# Consultando registro (original index 3868): Tipo=CC, Num=1088648630
# Resultado: No Registrado , no tiene sisben
# Esperando 2.34 segundos...
# Consultando registro (original index 3869): Tipo=CC, Num=27211140
# Resultado: No Registrado , no tiene sisben
# Esperando 2.59 segundos...
# Consultando registro (original index 3870): Tipo=TI, Num=1085927468
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_3870.xlsx'
# Esperando 3.72 segundos...
# Consultando registro (original index 3871): Tipo=TI, Num=1088652637
# Resultado: No Registrado , no tiene sisben
# Esperando 2.80 segundos...
# Consultando registro (original index 3872): Tipo=CC, Num=80226085
# Resultado: No Registrado , no tiene sisben
# Esperando 1.86 segundos...
# Consultando registro (original index 3873): Tipo=TI, Num=1030000480
# Resultado: Registrado, persona con sisben
# Esperando 1.80 segundos...
# Consultando registro (original index 3874): Tipo=TI, Num=1080697695
# Resultado: Registrado, persona con sisben
# Esperando 3.59 segundos...
# Consultando registro (original index 3875): Tipo=CC, Num=1130608660
# Resultado: No Registrado , no tiene sisben
# Esperando 1.08 segundos...
# Consultando registro (original index 3876): Tipo=CC, Num=5253767
# Resultado: No Registrado , no tiene sisben
# Esperando 2.80 segundos...
# ...
# Esperando 2.37 segundos...
# Consultando registro (original index 7984): Tipo=CC, Num=27210807
# Resultado: No Registrado , no tiene sisben
# Esperando 1.38 segundos...
# Consultando registro (original index 7985): Tipo=CC, Num=1088654260
# Resultado: No Registrado , no tiene sisben
# Esperando 2.54 segundos...
# Consultando registro (original index 7986): Tipo=CC, Num=1007602730
# Resultado: No Registrado , no tiene sisben
# Esperando 1.61 segundos...
# Consultando registro (original index 7987): Tipo=CC, Num=13039675
# Resultado: No Registrado , no tiene sisben
# Esperando 2.72 segundos...
# Consultando registro (original index 7988): Tipo=CC, Num=98342223
# Resultado: No Registrado , no tiene sisben
# Esperando 2.44 segundos...
# Consultando registro (original index 7989): Tipo=CC, Num=27211979
# Resultado: No Registrado , no tiene sisben
# Esperando 2.00 segundos...
# Consultando registro (original index 7990): Tipo=CC, Num=1088652554
# Resultado: No Registrado , no tiene sisben
# Esperando 1.22 segundos...
# Consultando registro (original index 7991): Tipo=CC, Num=98342003
# Resultado: No Registrado , no tiene sisben
# Esperando 2.61 segundos...
# Consultando registro (original index 7992): Tipo=CC, Num=27211241
# Resultado: No Registrado , no tiene sisben
# Esperando 2.05 segundos...
# Consultando registro (original index 7993): Tipo=CC, Num=27213433
# Resultado: No Registrado , no tiene sisben
# Esperando 2.49 segundos...
# Consultando registro (original index 7994): Tipo=CC, Num=5253878
# Resultado: No Registrado , no tiene sisben
# Esperando 1.53 segundos...
# Consultando registro (original index 7995): Tipo=CC, Num=27209687
# Resultado: No Registrado , no tiene sisben
# Esperando 3.41 segundos...
# Consultando registro (original index 7996): Tipo=CC, Num=36754785
# Resultado: No Registrado , no tiene sisben
# Esperando 3.70 segundos...
# Consultando registro (original index 7997): Tipo=TI, Num=1088651828
# Resultado: No Registrado , no tiene sisben
# Esperando 1.50 segundos...
# Consultando registro (original index 7998): Tipo=CC, Num=1004625149
# Resultado: No Registrado , no tiene sisben
# Esperando 3.10 segundos...
# Consultando registro (original index 7999): Tipo=CC, Num=27212003
# Resultado: No Registrado , no tiene sisben
# Esperando 1.58 segundos...
# Consultando registro (original index 8000): Tipo=TI, Num=1085911516
# Resultado: No Registrado , no tiene sisben
# Esperando 2.92 segundos...
# Consultando registro (original index 8001): Tipo=TI, Num=1088653864
# Resultado: No Registrado , no tiene sisben
# Esperando 3.57 segundos...
# Consultando registro (original index 8002): Tipo=CC, Num=1214746470
# Resultado: No Registrado , no tiene sisben
# Esperando 3.79 segundos...
# Consultando registro (original index 8003): Tipo=CC, Num=30712300
# Resultado: No Registrado , no tiene sisben
# Esperando 1.80 segundos...
# Consultando registro (original index 8004): Tipo=CC, Num=87102347
# Resultado: No Registrado , no tiene sisben
# Esperando 3.74 segundos...
# Consultando registro (original index 8005): Tipo=CC, Num=1085899353
# Resultado: No Registrado , no tiene sisben
# Esperando 2.34 segundos...
# Consultando registro (original index 8006): Tipo=TI, Num=1086422995
# Resultado: No Registrado , no tiene sisben
# Esperando 1.36 segundos...
# Consultando registro (original index 8007): Tipo=RC, Num=1086423918
# Resultado: No Registrado , no tiene sisben
# Esperando 3.10 segundos...
# Consultando registro (original index 8008): Tipo=CC, Num=27213885
# Resultado: No Registrado , no tiene sisben
# Esperando 1.99 segundos...
# Consultando registro (original index 8009): Tipo=CC, Num=1192717343
# Resultado: No Registrado , no tiene sisben
# Esperando 3.86 segundos...
# Consultando registro (original index 8010): Tipo=TI, Num=1088648031
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_8010.xlsx'
# Esperando 1.63 segundos...
# Consultando registro (original index 8011): Tipo=CC, Num=98342485
# Resultado: No Registrado , no tiene sisben
# Esperando 2.05 segundos...
# Consultando registro (original index 8012): Tipo=CC, Num=1088652154
# Resultado: No Registrado , no tiene sisben
# Esperando 3.40 segundos...
# Consultando registro (original index 8013): Tipo=RC, Num=1088654936
# Resultado: No Registrado , no tiene sisben
# Esperando 2.52 segundos...
# Consultando registro (original index 8014): Tipo=CC, Num=1088652304
# Resultado: No Registrado , no tiene sisben
# Esperando 2.02 segundos...
# Consultando registro (original index 8015): Tipo=CC, Num=1088649640
# Resultado: No Registrado , no tiene sisben
# Esperando 3.53 segundos...
# Consultando registro (original index 8016): Tipo=TI, Num=1088650846
# Resultado: No Registrado , no tiene sisben
# Esperando 1.96 segundos...
# Consultando registro (original index 8017): Tipo=CC, Num=27210585
# Resultado: No Registrado , no tiene sisben
# Esperando 2.38 segundos...
# Consultando registro (original index 8018): Tipo=CC, Num=1088653619
# Resultado: No Registrado , no tiene sisben
# Esperando 2.20 segundos...
# Consultando registro (original index 8019): Tipo=CC, Num=98342092
# Resultado: No Registrado , no tiene sisben
# Esperando 3.51 segundos...
# Consultando registro (original index 8020): Tipo=CC, Num=37005896
# Resultado: No Registrado , no tiene sisben
# Esperando 1.83 segundos...
# Consultando registro (original index 8021): Tipo=CC, Num=1004692183
# Resultado: No Registrado , no tiene sisben
# Esperando 1.75 segundos...
# Consultando registro (original index 8022): Tipo=CC, Num=27210446
# Resultado: No Registrado , no tiene sisben
# Esperando 1.34 segundos...
# Consultando registro (original index 8023): Tipo=CC, Num=98342414
# Resultado: No Registrado , no tiene sisben
# Esperando 2.81 segundos...
# Consultando registro (original index 8024): Tipo=CC, Num=27209996
# Resultado: No Registrado , no tiene sisben
# Esperando 3.07 segundos...
# Consultando registro (original index 8025): Tipo=CC, Num=98342847
# Resultado: No Registrado , no tiene sisben
# Esperando 2.99 segundos...
# Consultando registro (original index 8026): Tipo=RC, Num=1088601092
# Resultado: No Registrado , no tiene sisben
# Esperando 3.65 segundos...
# Consultando registro (original index 8027): Tipo=CC, Num=98342825
# Resultado: No Registrado , no tiene sisben
# Esperando 2.81 segundos...
# Consultando registro (original index 8028): Tipo=CC, Num=27213135
# Resultado: No Registrado , no tiene sisben
# Esperando 3.62 segundos...
# Consultando registro (original index 8029): Tipo=TI, Num=1088652020
# Resultado: No Registrado , no tiene sisben
# Esperando 3.03 segundos...
# Consultando registro (original index 8030): Tipo=CC, Num=1085301053
# Resultado: No Registrado , no tiene sisben
# Esperando 2.71 segundos...
# Consultando registro (original index 8031): Tipo=CC, Num=27211170
# Resultado: No Registrado , no tiene sisben
# Esperando 2.30 segundos...
# Consultando registro (original index 8032): Tipo=CC, Num=1088649251
# Resultado: No Registrado , no tiene sisben
# Esperando 3.34 segundos...
# Consultando registro (original index 8033): Tipo=CC, Num=5253804
# Resultado: No Registrado , no tiene sisben
# Esperando 2.64 segundos...
# Consultando registro (original index 8034): Tipo=CC, Num=1088651017
# Resultado: No Registrado , no tiene sisben
# Esperando 3.02 segundos...
# Consultando registro (original index 8035): Tipo=RC, Num=1088655218
# Resultado: No Registrado , no tiene sisben
# Esperando 2.30 segundos...
# Consultando registro (original index 8036): Tipo=CC, Num=1088654179
# Resultado: No Registrado , no tiene sisben
# Esperando 1.48 segundos...
# Consultando registro (original index 8037): Tipo=CC, Num=7559607
# Resultado: No Registrado , no tiene sisben
# Esperando 3.54 segundos...
# Consultando registro (original index 8038): Tipo=CC, Num=65702689
# Resultado: No Registrado , no tiene sisben
# Esperando 2.04 segundos...
# Consultando registro (original index 8039): Tipo=TI, Num=1088653063
# Resultado: No Registrado , no tiene sisben
# Esperando 1.12 segundos...
# Consultando registro (original index 8040): Tipo=CC, Num=98342239
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_8040.xlsx'
# Esperando 2.11 segundos...
# Consultando registro (original index 8041): Tipo=TI, Num=1088654387
# Resultado: No Registrado , no tiene sisben
# Esperando 3.75 segundos...
# Consultando registro (original index 8042): Tipo=CC, Num=27213098
# Resultado: No Registrado , no tiene sisben
# Esperando 3.59 segundos...
# Consultando registro (original index 8043): Tipo=TI, Num=1088652362
# Resultado: No Registrado , no tiene sisben
# Esperando 3.73 segundos...
# Consultando registro (original index 8044): Tipo=CC, Num=1088651592
# Resultado: No Registrado , no tiene sisben
# Esperando 1.18 segundos...
# Consultando registro (original index 8045): Tipo=TI, Num=1088653277
# Resultado: No Registrado , no tiene sisben
# Esperando 3.26 segundos...
# Consultando registro (original index 8046): Tipo=CC, Num=10530366
# Resultado: No Registrado , no tiene sisben
# Esperando 1.99 segundos...
# Consultando registro (original index 8047): Tipo=CC, Num=27209660
# Resultado: No Registrado , no tiene sisben
# Esperando 2.24 segundos...
# Consultando registro (original index 8048): Tipo=CC, Num=98342910
# Resultado: No Registrado , no tiene sisben
# Esperando 1.84 segundos...
# Consultando registro (original index 8049): Tipo=CC, Num=13039870
# Resultado: No Registrado , no tiene sisben
# Esperando 2.59 segundos...
# Consultando registro (original index 8050): Tipo=CC, Num=27212944
# Resultado: No Registrado , no tiene sisben
# Esperando 3.69 segundos...
# Consultando registro (original index 8051): Tipo=CC, Num=1088654026
# Resultado: No Registrado , no tiene sisben
# Esperando 2.33 segundos...
# Consultando registro (original index 8052): Tipo=CC, Num=1004691609
# Resultado: No Registrado , no tiene sisben
# Esperando 2.78 segundos...
# Consultando registro (original index 8053): Tipo=CC, Num=1088650885
# Resultado: No Registrado , no tiene sisben
# Esperando 2.96 segundos...
# Consultando registro (original index 8054): Tipo=TI, Num=1088653783
# Resultado: No Registrado , no tiene sisben
# Esperando 2.53 segundos...
# Consultando registro (original index 8055): Tipo=CC, Num=27209392
# Resultado: No Registrado , no tiene sisben
# Esperando 1.68 segundos...
# Consultando registro (original index 8056): Tipo=CC, Num=1085915040
# Resultado: No Registrado , no tiene sisben
# Esperando 2.02 segundos...
# Consultando registro (original index 8057): Tipo=CC, Num=27210958
# Resultado: No Registrado , no tiene sisben
# Esperando 3.60 segundos...
# Consultando registro (original index 8058): Tipo=CC, Num=1088651118
# Resultado: No Registrado , no tiene sisben
# Esperando 3.73 segundos...
# Consultando registro (original index 8059): Tipo=CC, Num=1088650421
# Resultado: No Registrado , no tiene sisben
# Esperando 3.42 segundos...
# Consultando registro (original index 8060): Tipo=TI, Num=1088653389
# Resultado: No Registrado , no tiene sisben
# Esperando 1.77 segundos...
# Consultando registro (original index 8061): Tipo=CC, Num=98342898
# Resultado: No Registrado , no tiene sisben
# Esperando 2.36 segundos...
# Consultando registro (original index 8062): Tipo=CC, Num=1088653969
# Resultado: No Registrado , no tiene sisben
# Esperando 1.25 segundos...
# Consultando registro (original index 8063): Tipo=RC, Num=1088655298
# Resultado: No Registrado , no tiene sisben
# Esperando 2.29 segundos...
# Consultando registro (original index 8064): Tipo=CC, Num=5253660
# Resultado: No Registrado , no tiene sisben
# Esperando 2.76 segundos...
# Consultando registro (original index 8065): Tipo=CC, Num=27209579
# Resultado: No Registrado , no tiene sisben
# Esperando 2.53 segundos...
# Consultando registro (original index 8066): Tipo=CC, Num=1192757490
# Resultado: No Registrado , no tiene sisben
# Esperando 3.94 segundos...
# Consultando registro (original index 8067): Tipo=RC, Num=1088655021
# Resultado: No Registrado , no tiene sisben
# Esperando 1.46 segundos...
# Consultando registro (original index 8068): Tipo=CC, Num=27212892
# Resultado: No Registrado , no tiene sisben
# Esperando 3.18 segundos...
# Consultando registro (original index 8069): Tipo=CC, Num=27209786
# Resultado: No Registrado , no tiene sisben
# Esperando 2.45 segundos...
# Consultando registro (original index 8070): Tipo=CC, Num=1088648702
# Resultado: No Registrado , no tiene sisben
# Progreso guardado en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_progreso_8070.xlsx'
# Esperando 3.97 segundos...
# Consultando registro (original index 8071): Tipo=CC, Num=1088648016
# Resultado: No Registrado , no tiene sisben
# Esperando 2.90 segundos...
# Consultando registro (original index 8072): Tipo=CC, Num=1088649716
# Resultado: No Registrado , no tiene sisben
# Esperando 3.25 segundos...
# Consultando registro (original index 8073): Tipo=TI, Num=1144825643
# Resultado: No Registrado , no tiene sisben
# Esperando 2.48 segundos...
# Consultando registro (original index 8074): Tipo=CC, Num=5255433
# Resultado: No Registrado , no tiene sisben
# Esperando 2.05 segundos...
# Consultando registro (original index 8075): Tipo=CC, Num=1088653721
# Resultado: No Registrado , no tiene sisben
# Esperando 2.95 segundos...
# Consultando registro (original index 8076): Tipo=TI, Num=1144827106
# Resultado: No Registrado , no tiene sisben
# Esperando 3.09 segundos...
# Consultando registro (original index 8077): Tipo=RC, Num=1088655002
# Resultado: No Registrado , no tiene sisben
# Esperando 3.98 segundos...
# Consultando registro (original index 8078): Tipo=CC, Num=27213898
# Resultado: No Registrado , no tiene sisben
# Esperando 1.94 segundos...
# Consultando registro (original index 8079): Tipo=CC, Num=1192774691
# Resultado: No Registrado , no tiene sisben
# Esperando 1.57 segundos...
# Consultando registro (original index 8080): Tipo=CC, Num=1004625562
# Resultado: No Registrado , no tiene sisben
# Esperando 1.84 segundos...
# Consultando registro (original index 8081): Tipo=CC, Num=1085906496
# Resultado: No Registrado , no tiene sisben
# Esperando 2.94 segundos...
# Consultando registro (original index 8082): Tipo=CC, Num=1085256739
# Resultado: No Registrado , no tiene sisben
# Esperando 1.77 segundos...
# Consultando registro (original index 8083): Tipo=TI, Num=1085914880
# Resultado: No Registrado , no tiene sisben
# Esperando 3.36 segundos...
# Consultando registro (original index 8084): Tipo=TI, Num=1085928431
# Resultado: No Registrado , no tiene sisben
# Esperando 1.38 segundos...
# Consultando registro (original index 8085): Tipo=CC, Num=27211062
# Resultado: No Registrado , no tiene sisben
# Esperando 1.16 segundos...
# Consultando registro (original index 8086): Tipo=CC, Num=5254968
# Resultado: No Registrado , no tiene sisben
# Esperando 1.53 segundos...
# Consultando registro (original index 8087): Tipo=CC, Num=98341767
# Resultado: No Registrado , no tiene sisben
# Esperando 3.07 segundos...
# Consultando registro (original index 8088): Tipo=CC, Num=1088652682
# Resultado: No Registrado , no tiene sisben
# Esperando 1.59 segundos...
# Consultando registro (original index 8089): Tipo=CC, Num=1004691997
# Resultado: No Registrado , no tiene sisben
# Esperando 1.23 segundos...
# Consultando registro (original index 8090): Tipo=CC, Num=32484902
# Resultado: Registrado, persona con sisben
# Esperando 1.75 segundos...
# Consultando registro (original index 8091): Tipo=CC, Num=1085316040
# Resultado: Registrado, persona con sisben
# Esperando 1.16 segundos...
# Consultando registro (original index 8092): Tipo=TI, Num=1080699394
# Resultado: Registrado, persona con sisben
# Esperando 3.88 segundos...
# Consultando registro (original index 8093): Tipo=CC, Num=98342379
# Resultado: Registrado, persona con sisben
# Esperando 2.51 segundos...
# Consultando registro (original index 8094): Tipo=CC, Num=87218422
# Resultado: Registrado, persona con sisben
# Esperando 1.75 segundos...
# Consultando registro (original index 8095): Tipo=CC, Num=1192800793
# Resultado: Registrado, persona con sisben
# Esperando 2.44 segundos...
# Consultando registro (original index 8096): Tipo=RC, Num=1245628031
# Resultado: Registrado, persona con sisben
# Esperando 3.28 segundos...
# Cerrando el navegador...
# ¡Proceso completado! Resultados guardados en 'Actualización Censo Resguardo Indigena de Guachucal - 2025 (1)_RESULTADOS_FINAL.xlsx'
# Fin del script.
